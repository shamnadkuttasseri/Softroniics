# %% [markdown]
# CNN-Convolutional Neural Network
#
# intention of this field is to enable machines to view the world as humans do.The advancments in Computer Vision with Deep Learning has been constructed and perfected with time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CNN layers
# * Convolution Layer
# * Polling Layer
# * Fully Connected Layer
